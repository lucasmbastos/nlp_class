# %% [markdown]
# # SKLearn Example

# %% [markdown]
# ## Imports

# %%
import os
import re

import sklearn
import pandas as pd
import nltk

# %% [markdown]
# ## Load and parse data

# %% [markdown]
# ### Raw data parsing

# %%
paths = {
    "train_pos": "../data/raw/aclImdb/train/pos/",
    "train_neg": "../data/raw/aclImdb/train/neg/",
    "test_pos": "../data/raw/aclImdb/test/pos/",
    "test_neg": "../data/raw/aclImdb/test/neg/"
}

# %%
# reviews = pd.Series([], name="REVIEW")
# score = pd.Series([], name="SCORE")

reviews = []
score = []

for path in paths.values():
    files = os.listdir(path)
    
    for file in files:
        file_score = re.search('\_([0-9]{1,2})\.', file).group(1)
        with open(path+file) as file_buffer:
            file_data = file_buffer.readlines()
            file_data = "".join(file_data)
        reviews.append(file_data)
        score.append(file_score)

        
dataset_as_dataframe = pd.DataFrame()
dataset_as_dataframe['REVIEW'] = reviews
dataset_as_dataframe['SCORE'] = score

# %%
dataset_as_dataframe
# Out:
#                                                   REVIEW SCORE
# 0      Dark Angel is a cross between Huxley's Brave N...    10
# 1      A serious comedy. Ross Hunter-produced movie v...     7
# 2      Those childhood memories...when things were ne...    10
# 3      This film lingered and lingered at a small mov...    10
# 4      Very interesting. The big twist wasn't as big ...     7
# 5      I would have rated the series a perfect 10 for...     9
# 6      My rating refers to the first 4 Seasons of Sta...     8
# 7      After the initial shock of realizing the guts ...    10
# 8      The Matador is a strange film. Its main charac...     7
# 9      Somehow, this movie manages to be invigorating...    10
# 10     Excellent movie, albeit slightly predictable. ...    10
# 11     I was really looking forward too seeing this m...     7
# 12     I have yet to see a film with Nolte in it that...     9
# 13     <br /><br />I just bought this movie on DVD an...     7
# 14     The title is the sound that one of the charact...     7
# 15     I have to point out, before you read this revi...     9
# 16     The absolute summum of the oeuvre of that craf...     9
# 17     Sandra Bernhard's Without You I'm Nothing, the...    10
# 18     A family (mother-Patricia Clarkson, father-Jak...     7
# 19     I used to love watching this. I had no idea it...    10
# 20     In April of 1965, CBS broadcast the first of B...    10
# 21     Lin McAdam (James Stewart) wins a rifle, a Win...     9
# 22     Legend of Dragoon is one of those little-known...     8
# 23     This sweeping drama has it all: top notch acti...    10
# 24     I'm not sure I understand where all these enth...    10
# 25     I finally got my wish to see this one in a cin...     7
# 26     Another in the they don't make em like that ca...     8
# 27     Kids - of whatever age - do not want to know a...     9
# 28     This German documentary, in English, is about ...     8
# 29     "I'll Take You There" tells of a woebegone man...     7
# ...                                                  ...   ...
# 49970  I challenge you to watch this film and deny th...     4
# 49971  Yeeee-Haa! <br /><br />I have seen it argued t...     3
# 49972  This is definitely the worst vampire flicks of...     1
# 49973  This is a comedy version of "Strangers on a Tr...     3
# 49974  Wow, i just witnessed one of the greatest poke...     4
# 49975  Trekkies is really not a movie about Star Trek...     3
# 49976  It wasn't until I saw Sidney Pollack in the pi...     1
# 49977  I just finished up this unofficial adaptation ...     3
# 49978  again such kind of zero-budget digital-video c...     1
# 49979  Other than cop rock and that show where the ki...     1
# 49980  The Grudge 2...Let's see. Don't get me wrong, ...     4
# 49981  **Maybe spoilers** **hard to spoil this thing ...     1
# 49982  I grabbed La Bandara because it reunited Jean ...     4
# 49983  Did the writers pay people to come up here and...     1
# 49984  I saw this movie a while ago and I was looking...     1
# 49985  STAR RATING: ***** Saturday Night **** Friday ...     4
# 49986  Whoa. I mean, whoa. I mean, whoa whoa.<br /><b...     4
# 49987  This movie was disappointing. After 15 years, ...     3
# 49988  I at first thought this little fantasy excursi...     1
# 49989  This "movie" and I say this lightly, is nothin...     1
# 49990  Impressive vision indeed, and some hot chicks ...     1
# 49991  Some directors take 2 and a half hours to tell...     1
# 49992  May Contain Spoilers.<br /><br />An innocent t...     2
# 49993  When i went to see this i thought, i liked the...     1
# 49994  This appalling piece of tripe was (convenientl...     1
# 49995  Contains spoilers. <br /><br />The British dir...     4
# 49996  OK, this 'horror' film was meant to be a joke,...     2
# 49997  A friend of mine decided to rent this thing, l...     2
# 49998  First let me say that those of you that voted ...     1
# 49999  You would have thought, given how much this ov...     1
#
# [50000 rows x 2 columns]

# %%
dataset_as_dataframe.to_csv("../data/processed/acllib_data.csv", index=False)

# %% [markdown]
# ### Loading from Processed data

# %%
usable_dataset = pd.read_csv("../data/processed/acllib_data.csv")
usable_dataset = usable_dataset.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Pre processing Data

# %%
tokenizer = nltk.tokenize.RegexpTokenizer("[a-z]+")

def pre_processing(review):
    review = review.lower()
    review = tokenizer.tokenize(review)
    return " ".join(review)

# %%
usable_dataset["REVIEW"] = usable_dataset["REVIEW"].map(pre_processing)
usable_dataset["SCORE"] = usable_dataset["SCORE"].map(lambda x: 0 if x <5 else 1)
usable_dataset
# Out:
#                                                   REVIEW  SCORE
# 0      this movie has a look and feel of many fresh d...      0
# 1      as i watched one of orson welles last contribu...      1
# 2      i just watched antwone fisher on bravo what an...      1
# 3      i couldn t believe how bad this film was and t...      0
# 4      the japanese cyber punk films have never reall...      1
# 5      four stories written by robert bloch about var...      1
# 6      whipped is minutes long this review is words l...      0
# 7      sergio martino has impressed me recently with ...      1
# 8      i watched this because a friend told me it was...      1
# 9      i was so offended by this film that i had to w...      0
# 10     let me start by saying you know a film is poor...      0
# 11     lifeforce was one of cannon films biggest flop...      1
# 12     the movie freddy s dead the final nightmare is...      1
# 13     joe d amato might have made some other notable...      0
# 14     the plot of this enjoyable mgm musical is cont...      1
# 15     comment like my comment is necessary we are ta...      1
# 16     this is seriously one of the best low budget b...      1
# 17     from the first to the last scene of the movie ...      1
# 18     a classy offering from amicus producer milton ...      1
# 19     if this movie should be renamed it should be t...      0
# 20     simply not the quality i expected from morris ...      0
# 21     fun movie the script is awful but the quality ...      1
# 22     by my kool aid drinkers remark i mean that the...      0
# 23     if there is a hell it contains a screening roo...      0
# 24     i love b movies but i like to be aware from th...      0
# 25     first of all i saw this movie when i was years...      0
# 26     this was a great movie that had a lot of under...      1
# 27     if this is a product from one of the biggest p...      0
# 28     i watched this film mistakenly thinking that i...      0
# 29     i ve seen this film three times and each time ...      1
# ...                                                  ...    ...
# 49970  i went to see this because of snipes statham b...      0
# 49971  the young dr fanshawe mark letheren an avid ar...      1
# 49972  worst movie ever made ever i have no words to ...      0
# 49973  huge ramones fan i do like the ramones and i s...      1
# 49974  certainly any others i have seen pale in compa...      1
# 49975  trekkies is really not a movie about star trek...      0
# 49976  anywhere but here is not exactly anything new ...      1
# 49977  with the plethora of repetitive and derivative...      0
# 49978  if you ve ever been to ukraine this movie is a...      1
# 49979  i ve seen some crappy movies in my life but th...      0
# 49980  i originally saw this very dark comedy around ...      1
# 49981  watching this movie really surprised me i have...      0
# 49982  i sat down to watch this film with much trepid...      1
# 49983  i rented this movie because i love kristanna l...      0
# 49984  think of this pilot as hawaii five o lite it s...      0
# 49985  it says that a girl named susan montford both ...      0
# 49986  i was expecting a b movie french musical after...      0
# 49987  of all the football films i have watched this ...      1
# 49988  the widower family man dan burns steve carell ...      1
# 49989  stewart moss stars as a scientist who is on a ...      0
# 49990  this is a baffling film br br the beauty in se...      0
# 49991  i first saw this movie at a premiere party in ...      1
# 49992  i came across this film by accident when listi...      1
# 49993  i bought jack o a number of months ago at a bl...      0
# 49994  finally third time lucky this film has been al...      1
# 49995  an intelligent and well obtained film worth to...      1
# 49996  if i had never seen an episode of the original...      0
# 49997  contrary to its title this film offers no spic...      0
# 49998  wow what a wonderful film making mr im has don...      1
# 49999  bah another tired desultory reworking of an ou...      0
#
# [50000 rows x 2 columns]

# %% [markdown]
# ## Train-test Split

# %%
train_dataframe, test_dataframe = sklearn.model_selection.train_test_split(usable_dataset,
                                             test_size=0.33,
                                             shuffle=True)

# %%
train_X = train_dataframe['REVIEW']
train_y = train_dataframe['SCORE']
test_X = test_dataframe['REVIEW']
test_y = test_dataframe['SCORE']

# %% [markdown]
# ## Feature Extraction (TF-IDF)

# %%
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(stop_words='english', max_features=200)

# %%
vectorizer.fit(train_dataframe['REVIEW'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=200, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
vectorizer.transform(usable_dataset.loc[0,'REVIEW'])
# Out:
# <1x200 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>
